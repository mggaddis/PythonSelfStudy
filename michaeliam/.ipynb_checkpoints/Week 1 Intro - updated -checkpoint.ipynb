# %% [markdown]
# #Tasks
#
#
# 1.	Fork the repository https://github.com/brianray/PythonSelfStudy
# 2.	Then clone your copy:  git clone https://github.com/michaeliam/PythonSelfStudy.git
# 3.	Cd into PythonSelfStudy/michaeliam/
# 4.	At shell: ipython notebook
# 5.	Create a notebook, call it “Part One” (or whatever you like) using Python 2 shell
# 6.	Maybe add “python ‘hello world’” or something
# 7.	git add “Part One.ipnb”
# 8.	git commit –am “adding notebooks”
# 9.	git push
# 10.	Then check to make sure your file made it onto github under *your* fork
# 11.	The issue a pull request to me so I get a copy of that file.

# %%
print "Hello, World!"
# Out:
# Hello, World!

# %%
import numpy as np
import pandas as pd
import requests
import StringIO

# %%
df=pd.read_csv("./Airbnb_train.csv")
print (df.head())
# Out:
#            id date_account_created  timestamp_first_active date_first_booking  \
# 0  gxn3p5htnn           2010-06-28          20090319043255                NaN
# 1  820tgsjxq7           2011-05-25          20090523174809                NaN
# 2  4ft3gnwmtx           2010-09-28          20090609231247         2010-08-02
# 3  bjjt8pjhuk           2011-12-05          20091031060129         2012-09-08
# 4  87mebub9p4           2010-09-14          20091208061105         2010-02-18
#
#       gender  age signup_method  signup_flow language affiliate_channel  \
# 0  -unknown-  NaN      facebook            0       en            direct
# 1       MALE   38      facebook            0       en               seo
# 2     FEMALE   56         basic            3       en            direct
# 3     FEMALE   42      facebook            0       en            direct
# 4  -unknown-   41         basic            0       en            direct
#
# ...

# %%
r = requests.get("https://data.consumerfinance.gov/api/views/s6ew-h6mp/rows.csv?accessType=DOWNLOAD")

# %%
new_csv = "\n".join(r.content.split("\n")[1:1000])

# %%
df = pd.read_csv(StringIO.StringIO(new_csv))

# %%
df.describe
# Out:
# <bound method DataFrame.describe of      02/13/2016         Credit reporting  \
# 0    02/12/2016          Debt collection
# 1    02/12/2016          Debt collection
# 2    02/12/2016         Credit reporting
# 3    02/12/2016         Credit reporting
# 4    02/12/2016         Credit reporting
# 5    02/12/2016          Debt collection
# 6    02/12/2016          Debt collection
# 7    02/12/2016                 Mortgage
# 8    02/12/2016          Debt collection
# 9    02/12/2016          Debt collection
# 10   02/12/2016          Debt collection
# 11   02/12/2016         Credit reporting
# 12   02/12/2016                 Mortgage
# 13   02/12/2016          Debt collection
# 14   02/12/2016          Debt collection
# 15   02/12/2016                 Mortgage
# 16   02/11/2016          Debt collection
# 17   02/11/2016            Consumer Loan
# 18   02/11/2016                 Mortgage
# 19   02/11/2016          Debt collection
# 20   02/11/2016          Debt collection
# ...

# %%
print (df.head())
# Out:
#    02/13/2016  Credit reporting                             Unnamed: 2  \
# 0  02/12/2016   Debt collection               Non-federal student loan
# 1  02/12/2016   Debt collection  Other (i.e. phone, health club, etc.)
# 2  02/12/2016  Credit reporting                                    NaN
# 3  02/12/2016  Credit reporting                                    NaN
# 4  02/12/2016  Credit reporting                                    NaN
#
#      Incorrect information on credit report  \
# 0           Disclosure verification of debt
# 1       Improper contact or sharing of info
# 2    Incorrect information on credit report
# 3    Incorrect information on credit report
# 4  Credit reporting company's investigation
#
#                   Information is not mine  Unnamed: 5  \
# 0  Not disclosed as an attempt to collect         NaN
# 1   Talked to a third party about my debt         NaN
# 2                          Account status         NaN
# ...
